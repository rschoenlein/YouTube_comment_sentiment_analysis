# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
comments = pd.read_csv(r'/Users/ryanschoenlein/Desktop/courses/udemy_real_world_python_data_analysis/YouTube_Text_Analysis/UScomments.csv', dtype='unicode', on_bad_lines='skip')

# %%
comments.head()
# Out:
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4  XpVt6Z1Gjjo                                         trending 😉     3
#
#   replies
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
comments.dropna(inplace=True)

# %%
comments.isnull().sum()
# Out:
# video_id        0
# comment_text    0
# likes           0
# replies         0
# dtype: int64

# %%
# !pip install textblob

# %%
from textblob import TextBlob

# %%
comments.head(0)
# Out:
# Empty DataFrame
# Columns: [video_id, comment_text, likes, replies]
# Index: []

# %%
TextBlob("Logan Paul it's yo big day ‼️‼️‼️").sentiment.polarity
# Out:
# 0.0

# %%
comments.shape
# Out:
# (691374, 4)

# %%
sample_df = comments[0:1000]

# %%
sample_df.shape
# Out:
# (1000, 4)

# %%
polarity = []

for comment in comments['comment_text']:
    try:
        polarity.append(TextBlob(comment).sentiment.polarity)
    except:
        polarity.append(0)

# %%
len(polarity)
# Out:
# 691374

# %%
comments['polarity'] = polarity

# %%
comments.head(10)
# Out:
#       video_id                                       comment_text likes  \
# 0  XpVt6Z1Gjjo                  Logan Paul it's yo big day ‼️‼️‼️     4
# 1  XpVt6Z1Gjjo  I've been following you from the start of your...     3
# 2  XpVt6Z1Gjjo                 Say hi to Kong and maverick for me     3
# 3  XpVt6Z1Gjjo                                MY FAN . attendance     3
# 4  XpVt6Z1Gjjo                                         trending 😉     3
# 5  XpVt6Z1Gjjo                            #1 on trending AYYEEEEE     3
# 6  XpVt6Z1Gjjo                               The end though 😭👍🏻❤️     4
# 7  XpVt6Z1Gjjo                               #1 trending!!!!!!!!!     3
# 8  XpVt6Z1Gjjo                        Happy one year vlogaversary     3
# 9  XpVt6Z1Gjjo  You and your shit brother may have single hand...     0
#
#   replies  polarity
# 0       0  0.000000
# 1       0  0.000000
# 2       0  0.000000
# 3       0  0.000000
# 4       0  0.000000
# 5       0  0.000000
# 6       0  0.000000
# ...

# %%
filter1 = comments['polarity']==1

# %%
positive_comments = comments[filter1]

# %%
filter2 = comments['polarity']==-1

# %%
negative_comments = comments[filter2]

# %%
# !pip install wordcloud

# %%
from wordcloud import WordCloud, STOPWORDS

# %%
total_positive_comments = ' '.join(positive_comments['comment_text'])

# %%
positive_comments_cloud = WordCloud(stopwords=set(STOPWORDS)).generate(total_positive_comments)

# %%
plt.imshow(positive_comments_cloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
total_negative_comments = ' '.join(negative_comments['comment_text'])

# %%
negative_comments_cloud = WordCloud(stopwords=set(STOPWORDS)).generate(total_negative_comments)

# %%
plt.imshow(negative_comments_cloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
